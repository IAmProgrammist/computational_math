# %% [markdown]
# Лабораторная работа №5
#
# Тема: Численное дифференцирование
#
# Цель работы: Изучить основные численные формулы дифференцирования, особенности их
# алгоритмизации.

# %% [markdown]
# Вариант 10
#
# $f(x) = 2 e^{-0.2x}sin(3x) + ln(1 + x^2)$
#
# 1) Найти точное и приближенные значения первой производной функции индивидуального
# задания в точке x (конкретное, не обращающее функцию в 0 значение, выбрать
# самостоятельно), использовав формулы численного дифференцирования первого, второго и
# четвертого порядка аппроксимации, вычислив или подобрав оптимальный шаг h. Для
# каждого полученного значения определить абсолютную, относительную погрешности
# (сопоставив точное и приближенные значения), проверить теоретическую оценку
# абсолютной погрешности r.
#
# $f'(x) = 2(3e^{-0.2x}cos(3x)-\frac{e^{-0.2x}sin(3x)}{5}) + \frac{2x}{x^2+1}$
#
# Пусть x = 0
#
# $f'(0) = 6$

# %%
import math

def f(x):
  return 2 * math.exp(-0.2 * x) * math.sin(3 * x) + math.log(1 + x**2)

def first(x):
  h = 0.01

  return (f(x + h) - f(x)) / h

actual = 6
print(first(0))
print("Абсолютная погрешность: ", abs(actual - first(0)))
print("Относительная погрешность: ", abs(actual - first(0)) / actual)
# Out:
# 5.997113330656742
# Абсолютная погрешность:  0.002886669343258319
# Относительная погрешность:  0.0004811115572097198

# %% [markdown]
# $a = 0, b = 0$
#
# $M_2 = max_{x \in [a, b]}|f''(x)| = 0.4$
#
# $M_0 = 0$
#
# $E = 0$
#
# $|r| \leq \frac{M_2 \cdot h}{2} + \frac{2E}{h} = \frac{0.4 \cdot 0.01}{2} = 0.002$

# %%
import math

def f(x):
  return 2 * math.exp(-0.2 * x) * math.sin(3 * x) + math.log(1 + x**2)

def second(x):
  h = 0.01

  return (f(x + h) - f(x - h)) / (2 * h)

actual = 6
print(second(0))
print("Абсолютная погрешность: ", abs(actual - second(0)))
print("Относительная погрешность: ", abs(actual - second(0)) / actual)
# Out:
# 5.999112038703212
# Абсолютная погрешность:  0.0008879612967875872
# Относительная погрешность:  0.00014799354946459786

# %% [markdown]
# $a = 0, b = 0$
#
# $M_3 = max_{x \in [a, b]}|f'''(x)| = 53.28$
#
# $|r| \leq \frac{M_3 \cdot h^2}{6} + \frac{E}{h} = \frac{53.28 \cdot 0.0001}{6} = 0.000888$

# %%
import math

def f(x):
  return 2 * math.exp(-0.2 * x) * math.sin(3 * x) + math.log(1 + x**2)

def fourth(x):
  h = 0.01

  return (f(x - 2 * h) - 8 * f(x - h) + 8 * f(x + h) - f(x + 2 * h)) / (12 * h)

actual = 6
print(fourth(0))
print("Абсолютная погрешность: ", abs(actual - fourth(0)))
print("Относительная погрешность: ", abs(actual - fourth(0)) / actual)
# Out:
# 5.999999845199748
# Абсолютная погрешность:  1.5480025172820433e-07
# Относительная погрешность:  2.580004195470072e-08

# %% [markdown]
# $a = 0, b = 0$
#
# $M_5 = max_{x \in [a, b]}|f'''(x)| = 464.448$
#
# $|r| \leq \frac{M_5 \cdot h^4}{30} + \frac{3E}{2h} = \frac{464.448 \cdot 0.01 ^ 4}{30} = 1.54816\cdot10^-7$

# %% [markdown]
# 2) Найти точное и приближенное значения второй производной функции индивидуального
# задания в точке x. Подобрать оптимальный шаг h экспериментально. Определить
# абсолютную, относительную погрешности.
#
# $f''(x) = 2(3(-3e^{-0.2x}sin(3x)-\frac{e^{-0.2x}cos(3x)}{5}) + \frac{e^{-0.2x}sin(3x)}{25}-\frac{3e^{-0.2x}cos(3x)}{5}) + \frac{2(1 - x^2)}{(x^2 + 1)^2}$
#
# $f''(0) = -0.4$

# %%
import math

def f(x):
  return 2 * math.exp(-0.2 * x) * math.sin(3 * x) + math.log(1 + x**2)

def differ2(x):
  h = 0.01

  return (f(x - h) - 2 * f(x) + f(x + h)) / (h ** 2)

actual = -0.4
print(differ2(0))
print("Абсолютная погрешность: ", abs(actual - differ2(0)))
print("Относительная погрешность: ", abs(actual - differ2(0)) / actual)
# Out:
# -0.39974160929413804
# Абсолютная погрешность:  0.0002583907058619772
# Относительная погрешность:  -0.000645976764654943

# %% [markdown]
# 3) Найти точное и приближенное значения третьей производной функции индивидуального
# задания в точке x. Подобрать оптимальный шаг h экспериментально. Определить
# абсолютную, относительную погрешности.
#
#
# $f'''(x) = 2(3(-3(3e^{-0.2x}cos(3x)-\frac{e^{-0.2x}sin(3x)}{5}) + \frac{3e^{-0.2x}sin(3x)}{5} + \frac{e^{-0.2x}cos(3x)}{25}) - \frac{3(-3e^{-0.2x}sin(3x) - \frac{e^{-0.2x}cos(3x)}{5})}{5} - \frac{e^{-0.2x}sin(3x)}{125} + \frac{3e^{-0.2x}cos(3x)}{25}) + \frac{2(-2x(x^2 + 1)^2 - 3x(1 - x^2)(x^2 + 1))}{(x^2 + 1)^4}$
#
# $f'''(0) = -53.28$

# %%
import math

def f(x):
  return 2 * math.exp(-0.2 * x) * math.sin(3 * x) + math.log(1 + x**2)

def differ3(x):
  h = 0.01

  return (f(x + 3*h / 2) - 3 * f(x + h / 2) + 3 * f(x - h / 2) - f(x - 3 * h / 2)) / (h ** 3)

actual = -53.28
print(differ3(0))
print("Абсолютная погрешность: ", abs(actual - differ3(0)))
print("Относительная погрешность: ", abs(actual - differ3(0)) / actual)
# Out:
# -53.27419466870375
# Абсолютная погрешность:  0.0058053312962513814
# Относительная погрешность:  -0.00010895892072543884

# %% [markdown]
# 4) Подготовить программы на языке Rust для всех численных расчетов.

# %%
# Установка Rust
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
import os
os.environ['PATH'] += ":/root/.cargo/bin"
# Проверка установки Rust
# !rustc --version
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# ...
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: default toolchain set to 'stable-x86_64-unknown-linux-gnu'
#
#   stable-x86_64-unknown-linux-gnu unchanged - rustc 1.78.0 (9b00956e5 2024-04-29)
#
#
# Rust is installed now. Great!
#
# To get started you may need to restart your current shell.
# This would reload your PATH environment variable to include
# Cargo's bin directory ($HOME/.cargo/bin).
#
# To configure your current shell, you need to source
# the corresponding env file under $HOME/.cargo.
#
# This is usually done by running one of the following (note the leading DOT):
# . "$HOME/.cargo/env"            # For sh/bash/zsh/ash/dash/pdksh
# source "$HOME/.cargo/env.fish"  # For fish
# rustc 1.78.0 (9b00956e5 2024-04-29)

# %%
# %%writefile lab5.rs
#
# fn f(x: f64) -> f64 {
#     2. * f64::exp(-0.2 * x) * f64::sin(3. * x) + f64::ln(1. + f64::powi(x, 2))
# }
#
# fn first(x: f64) -> f64 {
#     let h = 0.01;
#     return (f(x + h) - f(x)) / h;
# }
#
# fn second(x: f64) -> f64 {
#     let h = 0.01;
#     return (f(x + h) - f(x - h)) / (2. * h);
# }
#
# fn fourth(x: f64) -> f64 {
#     let h = 0.01;
#     return (f(x - 2. * h) - 8. * f(x - h) + 8. * f(x + h) - f(x + 2. * h)) / (12. * h);
# }
#
# fn differ2(x: f64) -> f64 {
#     let h = 0.01;
#     return (f(x - h) - 2. * f(x) + f(x + h)) / f64::powi(h, 2);
# }
#
# fn differ3(x: f64) -> f64 {
#     let h = 0.01;
#     return (f(x + 3.*h / 2.) - 3. * f(x + h / 2.) + 3. * f(x - h / 2.) - f(x - 3. * h / 2.)) / f64::powi(h, 3);
# }
#
# fn main() {
#     let x = 0.;
#
#     println!("Первая производная первого порядка: \n");
#     let actual = 6.;
#     println!("Абсолютная погрешность: {}", actual - first(x));
#     println!("Относительная погрешность: {}\n\n", (actual - first(x)) / actual);
#
#     println!("Первая производная второго порядка: \n");
#     let actual = 6.;
#     println!("Абсолютная погрешность: {}", actual - second(x));
#     println!("Относительная погрешность: {}\n\n", (actual - second(x)) / actual);
#
#     println!("Первая производная четвёртого порядка: \n");
#     let actual = 6.;
#     println!("Абсолютная погрешность: {}", actual - fourth(x));
#     println!("Относительная погрешность: {}\n\n", (actual - fourth(x)) / actual);
#
#     println!("Вторая производная: \n");
#     let actual = -0.4;
#     println!("Абсолютная погрешность: {}", actual - differ2(x));
#     println!("Относительная погрешность: {}\n\n", (actual - differ2(x)) / actual);
#
#     println!("Третья производная: \n");
#     let actual = -53.28;
#     println!("Абсолютная погрешность: {}", actual - differ3(x));
#     println!("Относительная погрешность: {}\n\n", (actual - differ3(x)) / actual);
# }
# Out:
# Overwriting lab5.rs

# %%
# Компиляция
# !rustc lab5.rs
# Запуск скомпилированной программы
# !./lab5
# Out:
# Первая производная первого порядка:
#
# Абсолютная погрешность: 0.002886669343258319
# Относительная погрешность: 0.0004811115572097198
#
#
# Первая производная второго порядка:
#
# Абсолютная погрешность: 0.0008879612967875872
# Относительная погрешность: 0.00014799354946459786
#
#
# Первая производная четвёртого порядка:
#
# Абсолютная погрешность: 0.00000015480025172820433
# Относительная погрешность: 0.00000002580004195470072
#
#
# Вторая производная:
#
# Абсолютная погрешность: -0.0002583907058619772
# Относительная погрешность: 0.000645976764654943
#
#
# Третья производная:
#
# Абсолютная погрешность: -0.0058053312962513814
# Относительная погрешность: 0.00010895892072543884

# %% [markdown]
# Вывод: в ходе лабораторной работы изучили основные численные формулы дифференцирования, особенности их
# алгоритмизации.
